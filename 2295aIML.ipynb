# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51295madhuri/Aiml-2025/blob/main/2295aIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %%
data = pd.read_csv('/content/wine quality.csv')

# %%
# Assuming 'quality' is the actual name of your target variable column
target_variable = 'quality'
unique_classes = data[target_variable].unique()
print(f"Unique classes in the target variable: {unique_classes}")
# Out:
# Unique classes in the target variable: [5 6 7 4 8 3]

# %%
features = ['pH', 'alcohol', 'citric acid']  # Replace with your feature names
for feature in features:
    plt.figure(figsize=(8, 4))
    sns.histplot(data[feature], kde=True, bins=30) # This line was indented too far, it should be aligned with plt.figure
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %%
X = data[features]
y = data[target_variable]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
print("\nFeature values before scaling (first 5 rows):")
print(X.head())
print("\nFeature values after scaling (first 5 rows):")
print(X_scaled[:5])
# Out:
# Feature values before scaling (first 5 rows):
#      pH  alcohol  citric acid
# 0  3.51      9.4         0.00
# 1  3.20      9.8         0.00
# 2  3.26      9.8         0.04
# 3  3.16      9.8         0.56
# 4  3.51      9.4         0.00
#
# Feature values after scaling (first 5 rows):
# [[ 1.27069495 -0.96338181 -1.36502663]
#  [-0.70892755 -0.59360107 -1.36502663]
#  [-0.32577481 -0.59360107 -1.16156762]
#  [-0.96436271 -0.59360107  1.48339955]
#  [ 1.27069495 -0.96338181 -1.36502663]]

# %%
data_cleaned = data.dropna()
print(f"\nData shape after removing rows with NaN values: {data_cleaned.shape}")
# Out:
# Data shape after removing rows with NaN values: (1143, 13)

# %%
import pandas as pd # Import the pandas library


# Assuming your data is in a CSV file named 'your_data.csv'
# Replace 'your_data.csv' with the actual file name
data = pd.read_csv('your_data.csv')

#Now, run your original code:
data_cleaned = data.dropna()
print(f"\nData shape after removing rows with NaN values: {data_cleaned.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-615ce07d2ea4> in <cell line: 1>()
# ----> 1 data_cleaned = data.dropna()
#       2 print(f"\nData shape after removing rows with NaN values: {data_cleaned.shape}")
#
# NameError: name 'data' is not defined

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
 z.predict(X_test)y_pre

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 0  5  1  0  0]
#  [ 1 67 28  0  0]
#  [ 1 32 58  8  0]
#  [ 0  2 18  6  0]
#  [ 0  0  1  1  0]]

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.63      0.70      0.66        96
#            6       0.55      0.59      0.57        99
#            7       0.40      0.23      0.29        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.57       229
#    macro avg       0.32      0.30      0.30       229
# weighted avg       0.55      0.57      0.56       229
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
